# %%
#!pip install xgboost
#!pip install pandas
import time
import datetime
import evaluate
from voiceClassify import VoiceClassify
import pprint

# %%
model = "speakers_all_data_noChroCon"

# %%
evaluate.train(model)
# Out:
# Making data set ready for classifier...
# Features extracted successfully...
# ************************************************************
# (3002, 40)
# (3002, 128)
# (3002, 6)
# (3002, 174)
# (3002,)
# Model saved successfully...
# Accuracy for train  1.0
# Accuracy for test  0.9467376830892144

# %%
vc = VoiceClassify(model)
result = vc.predict()
pprint.pprint(result)
# Out:
# Audio preprocessed..
# [(array(['S106'], dtype=object),
#   array([[5.3426982e-03, 1.4876615e-03, 6.2220614e-02, 3.2638767e-04,
#         4.3951649e-02, 2.5397632e-01, 4.1401933e-04, 2.3539503e-04,
#         6.9499278e-04, 7.9938653e-04, 3.0882351e-04, 2.5981068e-04,
#         4.0817415e-04, 2.4226015e-04, 6.2906602e-04, 2.3683198e-04,
#         2.0055755e-03, 2.2940680e-03, 5.6934211e-04, 7.9934037e-04,
#         3.5519870e-03, 3.0539883e-04, 3.5081248e-04, 9.0425095e-04,
#         3.5119930e-03, 1.1723391e-02, 3.8689698e-04, 3.5758339e-02,
#         6.5468403e-04, 1.3158149e-01, 2.9820498e-04, 3.5444106e-04,
#         3.4693594e-04, 3.0276991e-04, 5.3047767e-04, 2.4559998e-04,
#         2.5545494e-04, 1.2281399e-03, 1.7991128e-04, 9.6225349e-04,
#         4.8775750e-04, 2.6571241e-04, 3.7494441e-04, 1.6012875e-04,
#         2.0729615e-04, 5.4782757e-04, 2.9347074e-04, 3.5846231e-03,
#         4.5953132e-03, 6.1431999e-04, 5.1280227e-03, 2.6320148e-04,
# ...

# %%
result[0][0][0]
# Out:
# 'S106'
